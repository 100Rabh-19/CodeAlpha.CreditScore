# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.metrics import classification_report

# %%
df = pd.read_excel("C://Users//rabhs//Downloads//default of credit card clients.xls",header=1)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
num_cols = [
    'LIMIT_BAL', 'AGE',
    'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3',
    'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
    'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
    'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'
]

# %%
scaler = StandardScaler()
ct = ColumnTransformer(transformers=[
    ('standardscaler', scaler, num_cols)
], remainder='passthrough')

# %%
trf1 = ColumnTransformer([
    ('scale',StandardScaler(),num_cols)
])

# %%
trf2  =RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
pipe = make_pipeline(trf1,trf2)
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('scale', StandardScaler(),
#                                                   ['LIMIT_BAL', 'AGE',
#                                                    'BILL_AMT1', 'BILL_AMT2',
#                                                    'BILL_AMT3', 'BILL_AMT4',
#                                                    'BILL_AMT5', 'BILL_AMT6',
#                                                    'PAY_AMT1', 'PAY_AMT2',
#                                                    'PAY_AMT3', 'PAY_AMT4',
#                                                    'PAY_AMT5', 'PAY_AMT6'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(class_weight='balanced',
#                                         random_state=42))])

# %%
x = scaled_df.iloc[:, 1:25]  # Features
y = scaled_df.iloc[:, -1]    # Target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('scale', StandardScaler(),
#                                                   ['LIMIT_BAL', 'AGE',
#                                                    'BILL_AMT1', 'BILL_AMT2',
#                                                    'BILL_AMT3', 'BILL_AMT4',
#                                                    'BILL_AMT5', 'BILL_AMT6',
#                                                    'PAY_AMT1', 'PAY_AMT2',
#                                                    'PAY_AMT3', 'PAY_AMT4',
#                                                    'PAY_AMT5', 'PAY_AMT6'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(class_weight='balanced',
#                                         random_state=42))])

# %%
y_pred = pipe.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.95      0.89      4687
#          1.0       0.66      0.34      0.45      1313
#
#     accuracy                           0.82      6000
#    macro avg       0.75      0.64      0.67      6000
# weighted avg       0.80      0.82      0.79      6000

# %%
import pickle

# Save the model to a file
with open("random_forest_model.pkl", "wb") as file:
    pickle.dump(pipe, file)
